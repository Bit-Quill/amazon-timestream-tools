# %% [markdown]
# # Timestream Lambda Function Sample Application

# %% [markdown]
# This notebook demonstrates generating data, according to a schema defined by the user; deploying an AWS Lambda function to process it; and visualizing the data using Grafana.

# %% [markdown]
# ## Step 1: Generate Data

# %% [markdown]
# ## Imports

# %%
from abc import ABC, abstractmethod
import random
import time
from datetime import datetime, timedelta
import json

# %% [markdown]
# ## Data Generator Base Class Definition

# %%
class DataGenerator(ABC):
    start_date: datetime
    end_date: datetime
    frequency: timedelta
    num_entities: int

    def __init__(self, start_date: datetime, end_date: datetime, frequency: timedelta, num_entities: int):
        self.start_date = start_date
        self.end_date = end_date
        self.frequency = frequency
        self.num_entities = num_entities

    @abstractmethod
    def generate(self, num_records, entities) -> list:
        pass

    def _generate_date_range(self):
        return
    
    def _generate_random_string(self, length):
        """Generate a random alphanumeric string of a given length."""
        letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789"
        return ''.join(random.choice(letters) for _ in range(length))

# %% [markdown]
# ## DevOps Data Generator Subclass Definition

# %%
class DevOpsDataGenerator(DataGenerator):
    def generate(self) -> list:
        dates = self._generate_date_range()
        entities = []
        for _ in range(self.num_entities):
            entity = {
                "device_id": self._generate_random_string(9),
                "region": random.choice(["us-west-1", "us-east-1"]),
                # This allows the entity's measure values to be incremented without doing a costly
                # scan over previous records in the records list
                "most_recent_measures": {}
            }
            entities.append(entity)

        records = []
        current_date = self.start_date
        max_measure_variance = 1.2
        while current_date <= self.end_date:
            # Each entity has a record for a single timestamp
            for entity in entities:
                dimensions = []
                for dimension_name in entity:
                    if dimension_name != "most_recent_measures":
                        dimension = {
                            "Name": dimension_name,
                            "Value": entity[dimension_name]
                        }
                        dimensions.append(dimension)

                # Set initial values for measures
                measures = {
                    "energy_usage": random.uniform(1, 10),
                    "cpu_usage": random.uniform(2, 20)
                } if current_date == self.start_date else {
                    "energy_usage": entity["most_recent_measures"]["energy_usage"] + random.uniform(-max_measure_variance, max_measure_variance),
                    "cpu_usage": entity["most_recent_measures"]["cpu_usage"] + random.uniform(-max_measure_variance, max_measure_variance)
                }
                entity["most_recent_measures"] = measures

                record = {
                    "Dimensions": dimensions,
                    "Time": str(int(current_date.timestamp())), # Millisecond precision
                    "Measures": measures
                }
                records.append(record)
            current_date += self.frequency
        return records

# %%
# Generate data using the new schema format
generator = DevOpsDataGenerator(start_date=datetime(2024, 1, 1, 1), end_date=datetime(2024, 9, 10, 11), frequency=timedelta(days=1), num_entities=4)
sample_data = generator.generate()

# Print generated data
print(json.dumps(sample_data, indent=2))
# Out:
# [
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704099600",
#     "Measures": {
#       "energy_usage": 4.079206209313118,
#       "cpu_usage": 16.71543965248445
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704099600",
#     "Measures": {
#       "energy_usage": 4.170465147220728,
#       "cpu_usage": 3.7209129631883977
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704099600",
#     "Measures": {
#       "energy_usage": 4.175119484097989,
#       "cpu_usage": 15.836309009332224
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704099600",
#     "Measures": {
#       "energy_usage": 1.0474747099608956,
#       "cpu_usage": 7.296774374257138
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704186000",
#     "Measures": {
#       "energy_usage": 4.497504481289148,
#       "cpu_usage": 16.387404824160964
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704186000",
#     "Measures": {
#       "energy_usage": 4.03352044553675,
#       "cpu_usage": 3.8392466419655933
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704186000",
#     "Measures": {
#       "energy_usage": 4.642318561432436,
#       "cpu_usage": 16.9952634435982
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704186000",
#     "Measures": {
#       "energy_usage": 0.4212445627102094,
#       "cpu_usage": 6.809493401555994
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704272400",
#     "Measures": {
#       "energy_usage": 4.089122737951602,
#       "cpu_usage": 16.710099944001666
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704272400",
#     "Measures": {
#       "energy_usage": 4.857063684636977,
#       "cpu_usage": 2.694525967439745
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704272400",
#     "Measures": {
#       "energy_usage": 5.122208146984802,
#       "cpu_usage": 17.012726443422892
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704272400",
#     "Measures": {
#       "energy_usage": 0.3734280244544853,
#       "cpu_usage": 6.986220596099519
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704358800",
#     "Measures": {
#       "energy_usage": 2.99524463071064,
#       "cpu_usage": 16.548348073573727
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704358800",
#     "Measures": {
#       "energy_usage": 5.879998629991484,
#       "cpu_usage": 3.533385799785382
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704358800",
#     "Measures": {
#       "energy_usage": 5.003601973919706,
#       "cpu_usage": 16.25160241874272
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704358800",
#     "Measures": {
#       "energy_usage": 0.15527680577287784,
#       "cpu_usage": 7.954608410454889
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704445200",
#     "Measures": {
#       "energy_usage": 3.2734058276142344,
#       "cpu_usage": 17.652346235637797
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704445200",
#     "Measures": {
#       "energy_usage": 6.899363865793385,
#       "cpu_usage": 2.886565684562573
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704445200",
#     "Measures": {
#       "energy_usage": 5.199511919477687,
#       "cpu_usage": 17.181649677379
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704445200",
#     "Measures": {
#       "energy_usage": -1.032954033135415,
#       "cpu_usage": 7.486563994274771
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704531600",
#     "Measures": {
#       "energy_usage": 3.4052736529453496,
#       "cpu_usage": 16.68709429680203
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704531600",
#     "Measures": {
#       "energy_usage": 7.492810191079695,
#       "cpu_usage": 3.1552151862016595
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704531600",
#     "Measures": {
#       "energy_usage": 4.4228060617587435,
#       "cpu_usage": 17.674266396079123
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704531600",
#     "Measures": {
#       "energy_usage": -0.9655262462540424,
#       "cpu_usage": 6.700196490914351
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704618000",
#     "Measures": {
#       "energy_usage": 4.190204074334942,
#       "cpu_usage": 17.589438794328487
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704618000",
#     "Measures": {
#       "energy_usage": 6.425808679307747,
#       "cpu_usage": 3.9223971312384966
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704618000",
#     "Measures": {
#       "energy_usage": 4.857694340307248,
#       "cpu_usage": 16.855595660016387
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704618000",
#     "Measures": {
#       "energy_usage": -1.7396427479133287,
#       "cpu_usage": 7.148757415407961
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704704400",
#     "Measures": {
#       "energy_usage": 4.362589096225719,
#       "cpu_usage": 16.53240983250882
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704704400",
#     "Measures": {
#       "energy_usage": 6.004424071598941,
#       "cpu_usage": 3.0699680005460586
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704704400",
#     "Measures": {
#       "energy_usage": 4.932801050790266,
#       "cpu_usage": 16.664733093349614
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704704400",
#     "Measures": {
#       "energy_usage": -1.6366639106866163,
#       "cpu_usage": 7.904548938650187
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704790800",
#     "Measures": {
#       "energy_usage": 3.950404705005708,
#       "cpu_usage": 16.67373456586968
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704790800",
#     "Measures": {
#       "energy_usage": 5.661166598662582,
#       "cpu_usage": 3.976129726211452
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704790800",
#     "Measures": {
#       "energy_usage": 4.7941563678717385,
#       "cpu_usage": 16.105826131415522
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704790800",
#     "Measures": {
#       "energy_usage": -1.1089315108038094,
#       "cpu_usage": 8.594805746378539
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704877200",
#     "Measures": {
#       "energy_usage": 3.948637629676144,
#       "cpu_usage": 16.291399102106773
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704877200",
#     "Measures": {
#       "energy_usage": 5.4925378560229365,
#       "cpu_usage": 3.4304046402616692
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704877200",
#     "Measures": {
#       "energy_usage": 4.216166060412725,
#       "cpu_usage": 16.383571224070266
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704877200",
#     "Measures": {
#       "energy_usage": -0.3153091617908954,
#       "cpu_usage": 9.561759422957225
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704963600",
#     "Measures": {
#       "energy_usage": 2.758119109805163,
#       "cpu_usage": 15.55995740560407
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704963600",
#     "Measures": {
#       "energy_usage": 6.564586674893744,
#       "cpu_usage": 2.72783236147084
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1704963600",
#     "Measures": {
#       "energy_usage": 3.156344636972345,
#       "cpu_usage": 17.325080109031763
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1704963600",
#     "Measures": {
#       "energy_usage": -1.1823545325843372,
#       "cpu_usage": 8.436979953674063
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705050000",
#     "Measures": {
#       "energy_usage": 1.9196099213507642,
#       "cpu_usage": 15.955059479116013
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705050000",
#     "Measures": {
#       "energy_usage": 5.800212854596199,
#       "cpu_usage": 3.449331096573028
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705050000",
#     "Measures": {
#       "energy_usage": 3.8206120463009112,
#       "cpu_usage": 16.880698556306534
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705050000",
#     "Measures": {
#       "energy_usage": -2.3014677364472407,
#       "cpu_usage": 8.11821238298886
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705136400",
#     "Measures": {
#       "energy_usage": 2.2688800262567472,
#       "cpu_usage": 14.954708175789728
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705136400",
#     "Measures": {
#       "energy_usage": 4.842075908190866,
#       "cpu_usage": 4.555018805824995
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705136400",
#     "Measures": {
#       "energy_usage": 3.36828610897765,
#       "cpu_usage": 16.596779152901366
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705136400",
#     "Measures": {
#       "energy_usage": -2.4809911157846543,
#       "cpu_usage": 7.85789986628037
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705222800",
#     "Measures": {
#       "energy_usage": 3.1923757487948503,
#       "cpu_usage": 14.767554809364302
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705222800",
#     "Measures": {
#       "energy_usage": 3.8822528417266984,
#       "cpu_usage": 4.798434662306729
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705222800",
#     "Measures": {
#       "energy_usage": 4.0496734987692555,
#       "cpu_usage": 15.490137232382143
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705222800",
#     "Measures": {
#       "energy_usage": -3.383018036922437,
#       "cpu_usage": 8.192827929333966
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705309200",
#     "Measures": {
#       "energy_usage": 2.434875838749555,
#       "cpu_usage": 13.9495758732424
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705309200",
#     "Measures": {
#       "energy_usage": 3.1493686873708904,
#       "cpu_usage": 5.653714331208102
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705309200",
#     "Measures": {
#       "energy_usage": 2.874544819852691,
#       "cpu_usage": 15.889018300410262
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705309200",
#     "Measures": {
#       "energy_usage": -2.9407511993999718,
#       "cpu_usage": 8.324054131589653
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705395600",
#     "Measures": {
#       "energy_usage": 3.1365293050803245,
#       "cpu_usage": 14.851681972808507
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705395600",
#     "Measures": {
#       "energy_usage": 3.4806002230956476,
#       "cpu_usage": 6.373688654516042
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705395600",
#     "Measures": {
#       "energy_usage": 2.3776075014635225,
#       "cpu_usage": 14.796174969050236
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705395600",
#     "Measures": {
#       "energy_usage": -3.5977226522028913,
#       "cpu_usage": 7.318684051011845
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705482000",
#     "Measures": {
#       "energy_usage": 3.4256079943602824,
#       "cpu_usage": 15.56055003916855
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705482000",
#     "Measures": {
#       "energy_usage": 3.0557935768381537,
#       "cpu_usage": 5.890912709936825
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705482000",
#     "Measures": {
#       "energy_usage": 2.674029526718197,
#       "cpu_usage": 14.840886137303002
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705482000",
#     "Measures": {
#       "energy_usage": -2.8820776510587143,
#       "cpu_usage": 6.487350508226028
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705568400",
#     "Measures": {
#       "energy_usage": 3.878445832279172,
#       "cpu_usage": 16.561396319857202
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705568400",
#     "Measures": {
#       "energy_usage": 3.905290172428348,
#       "cpu_usage": 7.05059368788466
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705568400",
#     "Measures": {
#       "energy_usage": 1.6167809263856259,
#       "cpu_usage": 14.22519054684726
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705568400",
#     "Measures": {
#       "energy_usage": -2.0255472087089537,
#       "cpu_usage": 6.2795800510288995
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705654800",
#     "Measures": {
#       "energy_usage": 3.056653058951067,
#       "cpu_usage": 15.403339411925936
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705654800",
#     "Measures": {
#       "energy_usage": 3.1861521880671706,
#       "cpu_usage": 5.9865126231062336
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705654800",
#     "Measures": {
#       "energy_usage": 2.5467196287773293,
#       "cpu_usage": 15.143019268794463
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705654800",
#     "Measures": {
#       "energy_usage": -2.429198105869253,
#       "cpu_usage": 6.586302176189081
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705741200",
#     "Measures": {
#       "energy_usage": 2.8654331981388452,
#       "cpu_usage": 15.33474938462578
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705741200",
#     "Measures": {
#       "energy_usage": 3.516755167009001,
#       "cpu_usage": 6.887558071898598
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705741200",
#     "Measures": {
#       "energy_usage": 3.232916396187963,
#       "cpu_usage": 15.36089715554418
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705741200",
#     "Measures": {
#       "energy_usage": -2.480555453475386,
#       "cpu_usage": 7.25047788125908
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705827600",
#     "Measures": {
#       "energy_usage": 3.229255916553087,
#       "cpu_usage": 16.319435879340148
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705827600",
#     "Measures": {
#       "energy_usage": 2.34109392618297,
#       "cpu_usage": 7.049190030336746
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705827600",
#     "Measures": {
#       "energy_usage": 3.3437854630378068,
#       "cpu_usage": 15.77797449358153
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705827600",
#     "Measures": {
#       "energy_usage": -2.2414162522726335,
#       "cpu_usage": 6.784273887665189
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705914000",
#     "Measures": {
#       "energy_usage": 2.3770144684025,
#       "cpu_usage": 17.50594050920101
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705914000",
#     "Measures": {
#       "energy_usage": 2.3106223944823796,
#       "cpu_usage": 6.90831697115626
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1705914000",
#     "Measures": {
#       "energy_usage": 2.2196999414470886,
#       "cpu_usage": 16.020691072860306
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1705914000",
#     "Measures": {
#       "energy_usage": -2.4870093889185365,
#       "cpu_usage": 7.1098097196359475
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706000400",
#     "Measures": {
#       "energy_usage": 1.7825352135722485,
#       "cpu_usage": 17.464227165709257
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706000400",
#     "Measures": {
#       "energy_usage": 3.3673733044448353,
#       "cpu_usage": 6.204476875718184
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706000400",
#     "Measures": {
#       "energy_usage": 2.559982718946782,
#       "cpu_usage": 15.850334978256578
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706000400",
#     "Measures": {
#       "energy_usage": -2.1188095384763734,
#       "cpu_usage": 6.938458053511179
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706086800",
#     "Measures": {
#       "energy_usage": 0.5967999220649283,
#       "cpu_usage": 16.593307683854146
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706086800",
#     "Measures": {
#       "energy_usage": 4.470785887655981,
#       "cpu_usage": 5.188353648330846
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706086800",
#     "Measures": {
#       "energy_usage": 1.6977164235629851,
#       "cpu_usage": 16.9419163588328
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706086800",
#     "Measures": {
#       "energy_usage": -0.9817166536298354,
#       "cpu_usage": 6.302001034588444
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706173200",
#     "Measures": {
#       "energy_usage": 0.8417915978871533,
#       "cpu_usage": 16.240284751239486
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706173200",
#     "Measures": {
#       "energy_usage": 4.239008266388496,
#       "cpu_usage": 5.427558665648952
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706173200",
#     "Measures": {
#       "energy_usage": 2.502355023955284,
#       "cpu_usage": 16.703203814047654
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706173200",
#     "Measures": {
#       "energy_usage": -0.7708033639528622,
#       "cpu_usage": 7.201518161046933
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706259600",
#     "Measures": {
#       "energy_usage": 1.3554168156362258,
#       "cpu_usage": 15.899036868921629
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706259600",
#     "Measures": {
#       "energy_usage": 3.4272829683331274,
#       "cpu_usage": 6.011409607381337
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706259600",
#     "Measures": {
#       "energy_usage": 1.5471898328000377,
#       "cpu_usage": 15.557542173607425
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706259600",
#     "Measures": {
#       "energy_usage": 0.27895156903706786,
#       "cpu_usage": 7.229819856542622
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706346000",
#     "Measures": {
#       "energy_usage": 2.250498738929434,
#       "cpu_usage": 15.06240128772512
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706346000",
#     "Measures": {
#       "energy_usage": 3.9899397087337154,
#       "cpu_usage": 7.087906258620268
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706346000",
#     "Measures": {
#       "energy_usage": 2.6191564285506788,
#       "cpu_usage": 16.11018599226229
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706346000",
#     "Measures": {
#       "energy_usage": -0.07080188948534993,
#       "cpu_usage": 7.880898633779385
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706432400",
#     "Measures": {
#       "energy_usage": 2.823130735439382,
#       "cpu_usage": 15.157321847188769
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706432400",
#     "Measures": {
#       "energy_usage": 3.100765545363794,
#       "cpu_usage": 7.504227140947734
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706432400",
#     "Measures": {
#       "energy_usage": 3.1495227872105005,
#       "cpu_usage": 16.22803306452869
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706432400",
#     "Measures": {
#       "energy_usage": 0.5462487936696419,
#       "cpu_usage": 6.698913181356904
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706518800",
#     "Measures": {
#       "energy_usage": 2.992522302836237,
#       "cpu_usage": 14.558024632009468
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706518800",
#     "Measures": {
#       "energy_usage": 2.0699785756093023,
#       "cpu_usage": 7.159735328758385
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706518800",
#     "Measures": {
#       "energy_usage": 3.160746944490889,
#       "cpu_usage": 16.13236432400839
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706518800",
#     "Measures": {
#       "energy_usage": -0.18854129781613205,
#       "cpu_usage": 7.3685375270317515
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706605200",
#     "Measures": {
#       "energy_usage": 2.05928034322638,
#       "cpu_usage": 14.308847460456585
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706605200",
#     "Measures": {
#       "energy_usage": 1.5549574425010793,
#       "cpu_usage": 6.3885426171809625
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706605200",
#     "Measures": {
#       "energy_usage": 2.4340043546285504,
#       "cpu_usage": 15.78415258721771
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706605200",
#     "Measures": {
#       "energy_usage": 0.3054368176317954,
#       "cpu_usage": 7.065349549745802
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706691600",
#     "Measures": {
#       "energy_usage": 2.4291923610828037,
#       "cpu_usage": 14.672671429465073
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706691600",
#     "Measures": {
#       "energy_usage": 0.7114728816526075,
#       "cpu_usage": 5.475300884077323
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706691600",
#     "Measures": {
#       "energy_usage": 2.6708120817657166,
#       "cpu_usage": 16.036810588760467
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706691600",
#     "Measures": {
#       "energy_usage": -0.4108900978247949,
#       "cpu_usage": 6.103733988541053
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706778000",
#     "Measures": {
#       "energy_usage": 3.566077798759382,
#       "cpu_usage": 15.284855275408962
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706778000",
#     "Measures": {
#       "energy_usage": 0.027638560521620614,
#       "cpu_usage": 6.044690182956375
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706778000",
#     "Measures": {
#       "energy_usage": 3.0952398004141863,
#       "cpu_usage": 15.509580644451963
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706778000",
#     "Measures": {
#       "energy_usage": -1.4085067480432745,
#       "cpu_usage": 6.050154432181103
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706864400",
#     "Measures": {
#       "energy_usage": 2.7581084496485007,
#       "cpu_usage": 15.34143450171225
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706864400",
#     "Measures": {
#       "energy_usage": -0.4660975682607693,
#       "cpu_usage": 5.814667305346229
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706864400",
#     "Measures": {
#       "energy_usage": 1.9739181991882615,
#       "cpu_usage": 16.294060733659247
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706864400",
#     "Measures": {
#       "energy_usage": -1.6161369745550656,
#       "cpu_usage": 5.278652020600827
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706950800",
#     "Measures": {
#       "energy_usage": 3.5267948467675843,
#       "cpu_usage": 15.35898519392246
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706950800",
#     "Measures": {
#       "energy_usage": -0.34177366380202057,
#       "cpu_usage": 6.918273684566847
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1706950800",
#     "Measures": {
#       "energy_usage": 2.35998289362949,
#       "cpu_usage": 15.397512028575163
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1706950800",
#     "Measures": {
#       "energy_usage": -0.6268163175997203,
#       "cpu_usage": 5.594466007921258
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707037200",
#     "Measures": {
#       "energy_usage": 4.319114892808224,
#       "cpu_usage": 14.924257170275354
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707037200",
#     "Measures": {
#       "energy_usage": 0.7345273847946459,
#       "cpu_usage": 8.021529316947127
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1707037200",
#     "Measures": {
#       "energy_usage": 1.9542131715088487,
#       "cpu_usage": 15.984325344991255
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707037200",
#     "Measures": {
#       "energy_usage": 0.2919812422535335,
#       "cpu_usage": 6.589700147634917
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707123600",
#     "Measures": {
#       "energy_usage": 4.423480026141963,
#       "cpu_usage": 15.315411142873643
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707123600",
#     "Measures": {
#       "energy_usage": 0.5939241185183963,
#       "cpu_usage": 9.019771290984298
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1707123600",
#     "Measures": {
#       "energy_usage": 1.3093213574464233,
#       "cpu_usage": 15.773350225749672
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707123600",
#     "Measures": {
#       "energy_usage": 1.0360344835000725,
#       "cpu_usage": 5.992704279978156
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707210000",
#     "Measures": {
#       "energy_usage": 4.864945166515929,
#       "cpu_usage": 14.94327536343543
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707210000",
#     "Measures": {
#       "energy_usage": 1.6207247261983093,
#       "cpu_usage": 8.4511482750467
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1707210000",
#     "Measures": {
#       "energy_usage": 0.4934189458891902,
#       "cpu_usage": 16.64511960796902
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707210000",
#     "Measures": {
#       "energy_usage": 1.37693799024335,
#       "cpu_usage": 7.064029448460529
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707296400",
#     "Measures": {
#       "energy_usage": 5.512958608790368,
#       "cpu_usage": 14.44725176311312
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707296400",
#     "Measures": {
#       "energy_usage": 0.4498709625537627,
#       "cpu_usage": 7.423254457237985
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1707296400",
#     "Measures": {
#       "energy_usage": 0.8326674419731364,
#       "cpu_usage": 17.678352184681764
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707296400",
#     "Measures": {
#       "energy_usage": 1.9917705622677737,
#       "cpu_usage": 7.69620716048996
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707382800",
#     "Measures": {
#       "energy_usage": 5.14321918516268,
#       "cpu_usage": 14.796387151457214
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1707382800",
#     "Measures": {
#       "energy_usage": -0.3684849858161079,
#       "cpu_usage": 8.542326942968073
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
# ...
#     "Measures": {
#       "energy_usage": -0.15928423103616796,
#       "cpu_usage": 22.76590248336288
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1724918400",
#     "Measures": {
#       "energy_usage": -0.512790441501167,
#       "cpu_usage": 13.938991224904766
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1724918400",
#     "Measures": {
#       "energy_usage": 23.242999612462786,
#       "cpu_usage": 25.096546294289638
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1724918400",
#     "Measures": {
#       "energy_usage": 7.132493544367993,
#       "cpu_usage": 18.99143523238416
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725004800",
#     "Measures": {
#       "energy_usage": -0.04080417167830208,
#       "cpu_usage": 22.299336013137825
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725004800",
#     "Measures": {
#       "energy_usage": -1.2533056722797433,
#       "cpu_usage": 14.469839232238975
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725004800",
#     "Measures": {
#       "energy_usage": 22.411300907217765,
#       "cpu_usage": 24.495827340734266
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725004800",
#     "Measures": {
#       "energy_usage": 6.8694099450901955,
#       "cpu_usage": 17.99422577565155
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725091200",
#     "Measures": {
#       "energy_usage": -0.038067698206522005,
#       "cpu_usage": 22.042180661011407
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725091200",
#     "Measures": {
#       "energy_usage": -0.36816588404748396,
#       "cpu_usage": 13.289902798149697
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725091200",
#     "Measures": {
#       "energy_usage": 22.62254047807324,
#       "cpu_usage": 25.13821618490006
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725091200",
#     "Measures": {
#       "energy_usage": 6.304553165615225,
#       "cpu_usage": 17.004205889371807
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725177600",
#     "Measures": {
#       "energy_usage": 0.7879121765237729,
#       "cpu_usage": 21.51115810202231
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725177600",
#     "Measures": {
#       "energy_usage": -1.2557778174648961,
#       "cpu_usage": 13.141100164275072
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725177600",
#     "Measures": {
#       "energy_usage": 23.578156384549143,
#       "cpu_usage": 24.37851231204273
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725177600",
#     "Measures": {
#       "energy_usage": 7.458267838224355,
#       "cpu_usage": 15.94038579691541
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725264000",
#     "Measures": {
#       "energy_usage": 1.6047433174784096,
#       "cpu_usage": 20.55929859913905
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725264000",
#     "Measures": {
#       "energy_usage": -1.9805654162436974,
#       "cpu_usage": 13.461063179735437
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725264000",
#     "Measures": {
#       "energy_usage": 24.326765806453523,
#       "cpu_usage": 24.610440811731724
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725264000",
#     "Measures": {
#       "energy_usage": 8.137970403357796,
#       "cpu_usage": 16.231823874624816
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725350400",
#     "Measures": {
#       "energy_usage": 0.7905890887072371,
#       "cpu_usage": 19.8411549638924
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725350400",
#     "Measures": {
#       "energy_usage": -1.2578960983129173,
#       "cpu_usage": 13.222331218371504
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725350400",
#     "Measures": {
#       "energy_usage": 23.465121159066594,
#       "cpu_usage": 23.98860841368247
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725350400",
#     "Measures": {
#       "energy_usage": 7.313370354870466,
#       "cpu_usage": 15.27642979641617
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725436800",
#     "Measures": {
#       "energy_usage": 0.9099526662894852,
#       "cpu_usage": 19.00402931011781
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725436800",
#     "Measures": {
#       "energy_usage": -1.3737273480407115,
#       "cpu_usage": 14.116206968976993
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725436800",
#     "Measures": {
#       "energy_usage": 24.229217367231488,
#       "cpu_usage": 24.98060382029493
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725436800",
#     "Measures": {
#       "energy_usage": 8.315254151762986,
#       "cpu_usage": 14.651474686938649
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725523200",
#     "Measures": {
#       "energy_usage": -0.06581420635760982,
#       "cpu_usage": 19.474376290376917
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725523200",
#     "Measures": {
#       "energy_usage": -2.0059666185568035,
#       "cpu_usage": 14.5969669827354
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725523200",
#     "Measures": {
#       "energy_usage": 24.222648941768846,
#       "cpu_usage": 24.281717775741058
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725523200",
#     "Measures": {
#       "energy_usage": 7.215309641922579,
#       "cpu_usage": 14.256159603029081
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725609600",
#     "Measures": {
#       "energy_usage": 0.8569039893055047,
#       "cpu_usage": 19.25208241285485
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725609600",
#     "Measures": {
#       "energy_usage": -2.4533492073835923,
#       "cpu_usage": 15.395480328689223
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725609600",
#     "Measures": {
#       "energy_usage": 24.12536292439398,
#       "cpu_usage": 23.09542641511944
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725609600",
#     "Measures": {
#       "energy_usage": 6.928649703166075,
#       "cpu_usage": 13.567653566380237
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725696000",
#     "Measures": {
#       "energy_usage": 1.852566017393741,
#       "cpu_usage": 19.643753518578652
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725696000",
#     "Measures": {
#       "energy_usage": -2.306525079130938,
#       "cpu_usage": 14.968541714577274
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725696000",
#     "Measures": {
#       "energy_usage": 23.345376940771235,
#       "cpu_usage": 22.07505373740799
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725696000",
#     "Measures": {
#       "energy_usage": 7.090216588219128,
#       "cpu_usage": 14.01734846012648
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725782400",
#     "Measures": {
#       "energy_usage": 2.1468807705319377,
#       "cpu_usage": 18.598882599688775
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725782400",
#     "Measures": {
#       "energy_usage": -2.2742560882747065,
#       "cpu_usage": 14.092036941856877
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725782400",
#     "Measures": {
#       "energy_usage": 22.93584533311696,
#       "cpu_usage": 21.47307617639853
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725782400",
#     "Measures": {
#       "energy_usage": 8.190323843373452,
#       "cpu_usage": 13.329236195547674
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725868800",
#     "Measures": {
#       "energy_usage": 3.075676642221463,
#       "cpu_usage": 19.40707535127389
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725868800",
#     "Measures": {
#       "energy_usage": -2.751541241067663,
#       "cpu_usage": 14.340962806537252
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725868800",
#     "Measures": {
#       "energy_usage": 22.05143881638997,
#       "cpu_usage": 20.87493084162407
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725868800",
#     "Measures": {
#       "energy_usage": 8.198210503406868,
#       "cpu_usage": 12.379614527035244
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "UmSzYKCaL"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725955200",
#     "Measures": {
#       "energy_usage": 1.9856580417604734,
#       "cpu_usage": 18.50198434382507
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "WoqqgLg29"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725955200",
#     "Measures": {
#       "energy_usage": -2.7069265891625722,
#       "cpu_usage": 14.991532566615648
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "Cl5E4YTJF"
#       },
#       {
#         "Name": "region",
#         "Value": "us-west-1"
#       }
#     ],
#     "Time": "1725955200",
#     "Measures": {
#       "energy_usage": 21.083783152512922,
#       "cpu_usage": 20.525126107669927
#     }
#   },
#   {
#     "Dimensions": [
#       {
#         "Name": "device_id",
#         "Value": "DVIHykcTC"
#       },
#       {
#         "Name": "region",
#         "Value": "us-east-1"
#       }
#     ],
#     "Time": "1725955200",
#     "Measures": {
#       "energy_usage": 8.055602192531117,
#       "cpu_usage": 13.1397540698923
#     }
#   }
# ]

# %%
def generate_random_string(length=6):
    """Generate a random alphanumeric string of a given length."""
    letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789"
    return ''.join(random.choice(letters) for _ in range(length))

def generate_timestream_data(schema, num_records=10):
    """
    Generate mock Timestream records with random dimension values and measures based on an input schema.
    
    Parameters:
    - schema: A dictionary containing 'dimensions' and 'measures' lists.
      Dimensions define 'DimensionName' and can optionally define a list of 'options' for random selection.
      Measures define 'MeasureName', 'MeasureValueType', and optionally 'MeasureValueRange' or 'options'.
      Example:
      {
          "dimensions": [
              {"DimensionName": "region", "options": ["us-west-2", "us-east-1"]},
              {"DimensionName": "device_id"}  # Will randomly generate a value if no options are given
          ],
          "measures": [
              {"MeasureName": "cost", "MeasureValueType": "DOUBLE", "MeasureValueRange": [100.0, 500.0]},
              {"MeasureName": "energy_consumption", "MeasureValueType": "DOUBLE", "MeasureValueRange": [50.0, 300.0]},
              {"MeasureName": "status", "MeasureValueType": "VARCHAR", "options": ["OK", "FAIL"]}
          ]
      }
    - num_records: Number of records to generate.

    Returns:
    - List of records suitable for ingestion into Timestream.
    """

    records = []

    for _ in range(num_records):
        record_time = str(int(time.time_ns()))  # Use a common nanosecond timestamp for all measures in the record

        # Extract dimensions from the schema and generate random values if needed
        record_dimensions = []
        for dim in schema.get("dimensions", []):
            dimension_name = dim['DimensionName']
            dimension_value = random.choice(dim.get("options", [generate_random_string()]))
            
            record_dimensions.append({
                "Name": dimension_name,
                "Value": dimension_value
            })

        # Extract measures from the schema and generate random values
        record_measures = []
        for measure in schema.get("measures", []):
            measure_name = measure.get("MeasureName")
            measure_type = measure.get("MeasureValueType")
            
            if measure_type == "DOUBLE":
                measure_value = round(random.uniform(*measure.get("MeasureValueRange", [0.0, 100.0])), 2)
            elif measure_type == "VARCHAR":
                measure_value = random.choice(measure.get("options", ["default"]))
            else:
                raise ValueError(f"Unsupported MeasureValueType: {measure_type}")

            record_measures.append({
                "MeasureName": measure_name,
                "MeasureValue": str(measure_value),
                "MeasureValueType": measure_type
            })

        # Construct the final record with multiple measures and dimensions
        record = {
            "Dimensions": record_dimensions,  # Use the generated dimensions
            "Time": record_time,  # Same timestamp for all measures in this record
            "Measures": record_measures  # Use the collected measures
        }

        records.append(record)

    return records

# Example input schema with separated dimensions and measures
schema = {
    "dimensions": [
        {"DimensionName": "region", "options": ["us-west-2", "us-east-1"]},
        {"DimensionName": "device_id", "options": ["fhncipr94k", "1o30plfurn", "1f49apz086"]}  # Random string if no options are provided
    ],
    "measures": [
        {"MeasureName": "cost", "MeasureValueType": "DOUBLE", "MeasureValueRange": [100.0, 500.0]},
        {"MeasureName": "energy_consumption", "MeasureValueType": "DOUBLE", "MeasureValueRange": [50.0, 300.0]},
        {"MeasureName": "status", "MeasureValueType": "VARCHAR", "options": ["OK", "FAIL"]}
    ]
}

dataset = SERVER_DATASET

# Generate data using the new schema format
sample_data = generate_timestream_data(schema, num_records=1000)

# Print generated data
print(json.dumps(sample_data, indent=2))

# %% [markdown]
# ## Step 2: Deploy AWS Lambda Function

# %% [markdown]
# The following code will construct and deploy a Lambda function that ingests data to Timestream.

# %%
# AWS SDK and Lambda deployment
import boto3
import zipfile
import os
import json

REGION_NAME='us-west-2'
DATABASE_NAME = 'sample_app_database'
TABLE_NAME = 'sample_app_table'

# Initialize clients

iam_client = boto3.client('iam', region_name=REGION_NAME)
lambda_client = boto3.client('lambda', region_name=REGION_NAME)
sts_client = boto3.client('sts', region_name=REGION_NAME)
account_id = sts_client.get_caller_identity()['Account']

# Step 1: Create IAM Role for Lambda
role_name = "TimestreamLambdaRole"
assume_role_policy = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Principal": {"Service": "lambda.amazonaws.com"},
            "Action": "sts:AssumeRole"
        }
    ]
}

role_arn = ""

try:
    create_role_response = iam_client.create_role(
        RoleName=role_name,
        AssumeRolePolicyDocument=json.dumps(assume_role_policy),
        Description="Role for Lambda to write to Timestream"
    )
    print(f"Created IAM Role: {role_name}")
    role_arn = create_role_response['Role']['Arn']
except iam_client.exceptions.EntityAlreadyExistsException:
    print(f"IAM Role {role_name} already exists")
    try:
        role_arn = iam_client.get_role(RoleName=role_name)['Role']['Arn']
    except iam_client.exceptions.NoSuchEntityException:
        print("IAM Role could not be found")
        raise

# CloudWatch logs policy to be added to the role
cloudwatch_logs_policy = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Action": [
                "logs:CreateLogGroup",
                "logs:CreateLogStream",
                "logs:PutLogEvents"
            ],
            "Resource": f"arn:aws:logs:{REGION_NAME}:{account_id}:log-group:/aws/lambda/TimestreamIoTLambda*"
        }
    ]
}

# Add the CloudWatch logs policy to the role
try:
    iam_client.put_role_policy(
        RoleName=role_name,
        PolicyName='CloudWatchLogsPolicy',
        PolicyDocument=json.dumps(cloudwatch_logs_policy)
    )
    print(f"Attached CloudWatch logs policy to role: {role_name}")
except Exception as e:
    print(f"Error attaching CloudWatch logs policy: {e}")

# Step 2: Attach Policy to the IAM Role
policy_arn = "arn:aws:iam::aws:policy/AmazonTimestreamFullAccess"
iam_client.attach_role_policy(
    RoleName=role_name,
    PolicyArn=policy_arn
)

print(f"Attached Timestream write policy to {role_name}")

# Step 3: Create Lambda Function Code
lambda_function_code = '''
import json
import os
import boto3
from botocore.exceptions import ClientError

REGION_NAME = os.environ['REGION_NAME']
DATABASE_NAME = os.environ['DATABASE_NAME']
TABLE_NAME = os.environ['TABLE_NAME']

# Initialize the Timestream client
timestream_client = boto3.client('timestream-write', REGION_NAME)

# Define your table retention properties
RETENTION_PROPERTIES = {
    'MemoryStoreRetentionPeriodInHours': 24,  # Adjust as needed
    'MagneticStoreRetentionPeriodInDays': 365  # Adjust as needed
}

def create_timestream_database_and_table():
    """
    Create Timestream database and table if they do not exist.
    """
    try:
        # Create database if it does not exist
        timestream_client.create_database(DatabaseName=DATABASE_NAME)
        print(f"Database '{DATABASE_NAME}' created successfully.")
    except ClientError as e:
        if e.response['Error']['Code'] == 'ConflictException':
            print(f"Database '{DATABASE_NAME}' already exists.")
        else:
            raise e  # Raise if it's a different error

    try:
        # Create table if it does not exist
        timestream_client.create_table(
            DatabaseName=DATABASE_NAME,
            TableName=TABLE_NAME,
            RetentionProperties=RETENTION_PROPERTIES
        )
        print(f"Table '{TABLE_NAME}' created successfully in database '{DATABASE_NAME}'.")
    except ClientError as e:
        if e.response['Error']['Code'] == 'ConflictException':
            print(f"Table '{TABLE_NAME}' already exists in database '{DATABASE_NAME}'.")
        else:
            raise e  # Raise if it's a different error

def lambda_handler(event, context):
    """
    Lambda function to process the request and ingest records into Timestream.
    The function accepts a list of records, handles MULTI measure types, 
    and sends data in batches of 100 records to Timestream.
    """

    # Create the database and table if they do not exist
    create_timestream_database_and_table()

    try:
        # Extract the records from the event
        body = event.get('body', '{}')
        parsed_body = json.loads(body)
        records = parsed_body.get('records', [])
        print(records)
        if not records:
            return {
                "statusCode": 400,
                "body": json.dumps("No records found in the request.")
            }

        # Process records in batches of 100
        for i in range(0, len(records), 100):
            records_batch = records[i:i + 100]
            # Prepare the records for Timestream
            prepared_records = []

            for record in records_batch:
                dimensions = record.get("Dimensions", [])
                time_value = record.get("Time")
                measures = record.get("Measures", [])

                # Check if there are multiple measures, in which case we'll use MULTI
                if len(measures) > 1:
                    measure_value_type = 'MULTI'
                    multi_value_measure = {
                        'MeasureName': measures[0]['MeasureName'],  # Example MeasureName; Timestream expects just one for MULTI
                        'MeasureValues': [
                            {
                                'Name': m['MeasureName'],
                                'Value': m['MeasureValue'],
                                'Type': m['MeasureValueType']
                            }
                            for m in measures
                        ]
                    }
                    prepared_record = {
                        'Dimensions': dimensions,
                        'Time': time_value,
                        'TimeUnit': 'MILLISECONDS',
                        'MeasureName': multi_value_measure['MeasureName'],  # Set MULTI MeasureName
                        'MeasureValueType': measure_value_type,
                        'MeasureValues': multi_value_measure['MeasureValues']
                    }
                else:
                    # Handle the case where there is only one measure
                    measure = measures[0]
                    prepared_record = {
                        'Dimensions': dimensions,
                        'Time': time_value,
                        'TimeUnit': 'MILLISECONDS',
                        'MeasureName': measure['MeasureName'],
                        'MeasureValue': measure['MeasureValue'],
                        'MeasureValueType': measure['MeasureValueType']
                    }

                prepared_records.append(prepared_record)

            # Write to Timestream using the `write_records` API
            response = timestream_client.write_records(
                DatabaseName=DATABASE_NAME,
                TableName=TABLE_NAME,
                Records=prepared_records
            )
            print(f"Batch write successful for records {i} to {i + len(records_batch) - 1}: {response}")

        return {
            "statusCode": 200,
            "body": json.dumps(f"Successfully ingested {len(records)} records into Timestream.")
        }
    
    except ClientError as e:
        print(f"Failed to write to Timestream: {e}")
        return {
            "statusCode": 500,
            "body": json.dumps(f"Error writing to Timestream: {str(e)}")
        }
'''

lambda_name = "TimestreamIoTLambda"

# Save the Lambda function code to a file
lambda_function_file = "lambda_function.py"
with open(lambda_function_file, 'w') as f:
    f.write(lambda_function_code)

# Create a deployment package (zip file)
lambda_zip = "lambda_function.zip"
with zipfile.ZipFile(lambda_zip, 'w') as zipf:
    zipf.write(lambda_function_file)

# Step 4: Deploy Lambda Function
lambda_name = "TimestreamIoTLambda"
try:
    with open(lambda_zip, 'rb') as f:
        lambda_client.create_function(
            FunctionName=lambda_name,
            Runtime='python3.12',
            Role=role_arn,
            Handler='lambda_function.lambda_handler',
            Architectures=['arm64'],
            Code={'ZipFile': f.read()},
            Environment={
                'Variables': {
                    'REGION_NAME': REGION_NAME,
                    'DATABASE_NAME': DATABASE_NAME,
                    'TABLE_NAME': TABLE_NAME
                }
            },
            Timeout=30,
            MemorySize=128
        )
    print(f"Lambda function {lambda_name} created successfully.")
except lambda_client.exceptions.ResourceConflictException:
    print(f"Lambda function {lambda_name} already exists.")

# Clean up the files
os.remove(lambda_function_file)
os.remove(lambda_zip)

# Step 4: Add a resource policy to allow invocation via the function URL

try:
    lambda_client.add_permission(
        FunctionName=lambda_name,
        StatementId='FunctionURLAllowInvoke',
        Action='lambda:InvokeFunctionUrl',
        Principal=role_arn,
        FunctionUrlAuthType='AWS_IAM'
    )
    print(f"Added resource policy to allow function URL invocation for {lambda_name}.")
except lambda_client.exceptions.ResourceConflictException:
    print(f"Resource policy for {lambda_name} already exists.")

# Create or get the Lambda Function URL
try:
    response = lambda_client.create_function_url_config(
        FunctionName=lambda_name,
        AuthType='AWS_IAM'
    )
    function_url = response['FunctionUrl']
    print(f"Lambda Function URL: {function_url}")
except lambda_client.exceptions.ResourceConflictException:
    # If the URL configuration already exists, retrieve it
    response = lambda_client.get_function_url_config(FunctionName=lambda_name)
    function_url = response['FunctionUrl']
    print(f"Lambda Function URL (existing): {function_url}")
# Out:
# IAM Role TimestreamLambdaRole already exists
# Attached CloudWatch logs policy to role: TimestreamLambdaRole
# Attached Timestream write policy to TimestreamLambdaRole
# Lambda function TimestreamIoTLambda created successfully.
# Added resource policy to allow function URL invocation for TimestreamIoTLambda.
# Lambda Function URL (existing): https://stki3begraoqpcarqe7l4olplm0kpwjv.lambda-url.us-west-2.on.aws/

# %% [markdown]
# ## Step 3: Send Data to the Lambda Function

# %% [markdown]
# The following code will send the generated sample data to the Lambda function's URL with SigV4 authenticated requests, ensuring requests do not exceed Lambda's limit of 6 MB.

# %%
import os
import json
import requests
import boto3
from botocore.auth import SigV4Auth
from botocore.awsrequest import AWSRequest

MAX_REQUEST_SIZE = 6 * 1024 * 1024  # 6 MB in bytes

def send_data_to_lambda(data):
    """Sends generated data to the Lambda function in chunks."""
    service = 'lambda'
    region = REGION_NAME
    method = "POST"

    session = boto3.Session(region_name=region)

    # Calculate the size of the entire data payload
    data_payload = json.dumps({'records': data})
    total_size = len(data_payload.encode('utf-8'))

    # Check if the total size exceeds the maximum request size
    if total_size <= MAX_REQUEST_SIZE:
        send_request(session, method, data_payload)
    else:
        # Chunk the data if it's too large
        chunk_size = MAX_REQUEST_SIZE - len(b'{"records":[]}')  # Reserve space for the JSON structure
        chunks = [data[i:i + chunk_size] for i in range(0, len(data), chunk_size)]
        for chunk in chunks:
            chunk_payload = json.dumps({'records': chunk})
            send_request(session, method, chunk_payload)

def send_request(session, method, payload):
    """Sends the request to the Lambda function."""
    request = AWSRequest(
        method=method,
        url=function_url,
        headers={'Content-Type': 'application/json'},
        data=payload
    )

    SigV4Auth(session.get_credentials(), 'lambda', REGION_NAME).add_auth(request)

    try:
        response = requests.request(method, function_url, headers=dict(request.headers), data=payload, timeout=30)
        response.raise_for_status()
        print(f'Response Status: {response.status_code}')
        print(f'Response Body: {response.content.decode("utf-8")}')
    except Exception as e:
        print(f'Error: {e}')

# Send sample data to the Lambda function
send_data_to_lambda(sample_data)
# Out:
# Error: 502 Server Error: Bad Gateway for url: https://stki3begraoqpcarqe7l4olplm0kpwjv.lambda-url.us-west-2.on.aws/

# %% [markdown]
# ## Step 4: Configure Grafana

# %% [markdown]
# ### Grafana Configuration Steps
# 1. Open Grafana.
# 2. Add a new data source with the name "timestream_sample_app_database".
# 3. Create a new dashboard using the provided `dashboard.json`.
